# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import libraries
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import norm
import statsmodels.api as sm

# Import Matplotlib for visualization
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import pyplot
from matplotlib import style
plt.style.use('ggplot')
import seaborn as sns
from matplotlib import rcParams

# figure size in inches
rcParams['figure.figsize'] = 10, 7
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# dataset from the Classification task in the privious question
data = pd.read_csv('/content/drive/MyDrive/Combyne Data/df00z.csv', index_col = 0)
data.head()
# Out:
#    screen_view  item_added  item_removed  ...  comment_posted  retentionScore  churn
# 0   -54.160145  -19.351744     -3.586996  ...       -0.293090        0.100652      0
# 1   -60.158077  -19.333639     -3.581750  ...       -0.291011        0.158661      0
# 2   -60.159478  -19.334463     -3.582734  ...       -0.249012        0.075264      1
# 3   -60.158729  -19.334558     -3.582421  ...       -0.200780        0.111569      0
# 4   -60.156281  -19.334639     -3.582108  ...        5.595428        0.138947      0
#
# [5 rows x 8 columns]

# %%
Y = data['churn']
X = data[['screen_view', 'item_added', 'item_removed', 'outfit_liked',
       'item_saved', 'comment_posted', 'retentionScore']]

# %%
X = sm.add_constant(X)
reg = sm.OLS(Y, X).fit()
prediction = reg.predict(X)

reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  churn   R-squared:                       0.763
# Model:                            OLS   Adj. R-squared:                  0.763
# Method:                 Least Squares   F-statistic:                 1.720e+05
# Date:                Mon, 27 Sep 2021   Prob (F-statistic):               0.00
# Time:                        04:15:28   Log-Likelihood:                -1792.4
# No. Observations:              373296   AIC:                             3601.
# Df Residuals:                  373288   BIC:                             3687.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# The Regression Line is as followed

# %%
data.columns

# Independent Variable
X1 = data[['screen_view', 'item_added', 'item_removed',  'retentionScore']]

# Dependent Variable
Y = data['churn']

# %%
X1 = sm.add_constant(X1)
reg = sm.OLS(Y, X1).fit()
prediction = reg.predict(X1)

reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  churn   R-squared:                       0.763
# Model:                            OLS   Adj. R-squared:                  0.763
# Method:                 Least Squares   F-statistic:                 3.009e+05
# Date:                Mon, 27 Sep 2021   Prob (F-statistic):               0.00
# Time:                        04:16:40   Log-Likelihood:                -1794.2
# No. Observations:              373296   AIC:                             3598.
# Df Residuals:                  373291   BIC:                             3653.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# Y = 1.2061
#     + 0.000003782 screen_view - 0.00007713 item_added + 0.00003891 item_removed - 7.2311 retentionScore
